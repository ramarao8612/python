# %% [markdown]
# STRING:it is an collection of the characters.
# Strings in python are surrounded by either single quotation marks, or double quotation marks.
#
# 'hello' is the same as "hello"
# Quotes Inside Quotes:
# You can use quotes inside a string, as long as they don't match the quotes surrounding the string:
# print("It's alright")
# print("He is called 'Johnny'")
# print('He is called "Johnny"')

# %%
a="hi" 
print(a)
# Out:
# hi

# %%
#looping through a string. 
for x in "onion":
  print(x)
# Out:
# o
# n
# i
# o
# n

# %%
#length of the string
a = "Hello, World!"
print(len(a))
# Out:
# 13

# %% [markdown]
# slicing string:you can return a range of characters by using the slice syntax.
#
# Specify the start index and the end index, separated by a colon, to return a part of the string

# %%
b = "Hello, World!"
print(b[2:5])             #between given range
# Out:
# llo

# %%
b = "Hello, World!"
print(b[:5])         #start to given range
# Out:
# Hello

# %%
b = "Hello, World!"
print(b[2:])         #given position to end
# Out:
# llo, World!

# %%
 b = "Hello, World!"
print(b[-5:-2])                                             #negative indexing:it start slice from end of the string
# Out:
# orl

# %%
a = "Hello, World!"
print(a.upper())                                          #upper case

a = "Hello, World!"
print(a.lower())                                          #lower case 

a = " Hello, World! "
print(a.strip())                                         #it removes white space
# Out:
# HELLO, WORLD!
# hello, world!
# Hello, World!

# %%
a = "Hello, World!"
print(a.replace("H", "J"))        #replace the string                 

a = "Hello, World!"
print(a.split(","))                 #split the string.
# Out:
# Jello, World!
# ['Hello', ' World!']

# %%
#String Concatenation
#To concatenate, or combine, two strings you can use the + operator 

a = "Hello"
b = "World"
c = a + b
print(c) 

a = "Hello"
b = "World"
c = a + " " + b
print(c)                                   #to provide space between twonstrings we use " "
# Out:
# HelloWorld
# Hello World

# %%
#fstring:we use fstring to combine string and the integer. 
age = 36
txt = f"My name is ram, I am {age}"
print(txt) 

price = 59
txt = f"The price is {price} dollars"
print(txt)
# Out:
# My name is ram, I am 36
# The price is 59 dollars

# %%
#string methods 
text = "hello world"
print(text.capitalize())   # Hello world
print("HELLO".lower())   # hello
print("hello".upper())   # HELLO
print("hello world".title())   # Hello World
print("HeLLo".swapcase())   # hEllO
print("  hello  ".strip())   # hello
print("  hello".lstrip())   # hello
print("hello  ".rstrip())   # hello
print("hello".find("l"))   # 2
print("hello".index("e"))   # 1
print("I like Java".replace("Java", "Python"))
print("banana".count("a"))   # 3
text = "apple,banana"
print(text.split(","))   # ['apple', 'banana']
words = ["I", "love", "Python"]
print(" ".join(words))   # I love Python
#check methods. 
print("abc123".isalnum())   # True
print("abc".isalpha())   # True
print("123".isdigit())   # True
print("HELLO".isupper())   # True
#alignment methods 
print("hi".center(10, "-"))   # ----hi----
print("hi".ljust(10, "-"))   # hi--------
print("hi".rjust(10, "-"))   # --------hi 
#partition
print("hello-world".partition("-")) # ('hello', '-', 'world') 
#formatting 
name = "Rama"
print("Hello {}".format(name))   # Hello Rama
#advanced 
print("7".zfill(3))   # 007
print("bad word".replace("bad", "***"))
# Out:
# Hello world
# hello
# HELLO
# Hello World
# hEllO
# hello
# hello
# hello
# 2
# 1
# I like Python
# 3
# ['apple', 'banana']
# I love Python
# True
# True
# True
# True
# ----hi----
# hi--------
# --------hi
# ('hello', '-', 'world')
# Hello Rama
# 007
# *** word

# %%
#palindrome 
text = "madam"

if text == text[::-1]:
    print("Palindrome")
else:
    print("Not Palindrome")
# Out:
# Palindrome

# %%
#count vowels and consonants.
text = "hello world"

vowels = "aeiou"
v_count = 0
c_count = 0

for ch in text.lower():
    if ch.isalpha():
        if ch in vowels:
            v_count += 1
        else:
            c_count += 1

print("Vowels:", v_count)
print("Consonants:", c_count)
# Out:
# Vowels: 3
# Consonants: 7

# %%
#booleans 
#Booleans represent one of two values: True or False. 
a = 200
b = 33

if b > a:
  print("b is greater than a")
else:
  print("b is not greater than a")
# Out:
# b is not greater than a

# %%
#The bool() function allows you to evaluate any value, and give you True or False in return 
print(bool("Hello"))
print(bool(15)) 
print(bool())
# Out:
# True
# True
# False

# %% [markdown]
# LIST:Lists are used to store multiple items in a single variable.
#
# Lists are one of 4 built-in data types in Python used to store collections of data, the other 3 are Tuple, Set, and Dictionary, all with different qualities and usage.
#
# Lists are created using square brackets:

# %%
this_list = ["apple", "banana", "cherry"]
print(this_list)
# Out:
# ['apple', 'banana', 'cherry']

# %% [markdown]
# List Items,
# List items are ordered, changeable, and allow duplicate values.
#
# List items are indexed, the first item has index [0], the second item has index [1] etc.
#
# Ordered:
# When we say that lists are ordered, it means that the items have a defined order, and that order will not change.
#
# If you add new items to a list, the new items will be placed at the end of the list.
#
# Note: There are some list methods that will change the order, but in general: the order of the items will not change.
#
# Changeable:
# The list is changeable, meaning that we can change, add, and remove items in a list after it has been created.
#
# Allow Duplicates:
# Since lists are indexed, lists can have items with the same value:
#
# Example:
# Lists allow duplicate values:

# %%
thislist = ["apple", "banana", "cherry", "apple", "cherry"]
print(thislist)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
thislist = ["apple", "banana", "cherry"]
print(len(thislist)) 

thislist = ["apple", "banana", "cherry"]
print(thislist[1])                           #ACCESS LIST 

thislist = ["apple", "banana", "cherry"]
print(thislist[-1])                          #NEGATIVE INDEXING. 

thislist = ["apple", "banana", "cherry"]
if "apple" in thislist:
  print("Yes, 'apple' is in the fruits list")  #To determine if a specified item is present in a list use the in keyword 

thislist = ["apple", "banana", "cherry"]
thislist[1] = "blackcurrant"
print(thislist)                                 #list change items  

thislist = ["apple", "banana", "cherry", "orange", "kiwi", "mango"]
thislist[1:3] = ["blackcurrant", "watermelon"]
print(thislist)                                  #replaceing list values. 
thislist[1:2] = ["blackcurrant", "watermelon"] 
print(thislist)
thislist = ["apple", "banana", "cherry"]
thislist[1:3] = ["watermelon"]
print(thislist)                                             #replacing second and third value with one value 

#the insert() method inserts an item at the specified index 
thislist = ["apple", "banana", "cherry"]
thislist.insert(2, "watermelon")
print(thislist) 

#To append elements from another list to the current list, use the extend() method 
thislist = ["apple", "banana", "cherry"]
tropical = ["mango", "pineapple", "papaya"]
thislist.extend(tropical)
print(thislist) 

thislist = ["apple", "banana", "cherry"]
thislist.remove("banana")                            #remove 
print(thislist) 
thislist.pop(1)                                     #pop
print(thislist)  
del thislist[0]                                    #del
print(thislist)
# Out:
# 3
# banana
# cherry
# Yes, 'apple' is in the fruits list
# ['apple', 'blackcurrant', 'cherry']
# ['apple', 'blackcurrant', 'watermelon', 'orange', 'kiwi', 'mango']
# ['apple', 'blackcurrant', 'watermelon', 'watermelon', 'orange', 'kiwi', 'mango']
# ['apple', 'watermelon']
# ['apple', 'banana', 'watermelon', 'cherry']
# ['apple', 'banana', 'cherry', 'mango', 'pineapple', 'papaya']
# ['apple', 'cherry']
# ['apple']
# []

# %% [markdown]
# looping through a list

# %%
thislist = ["apple", "banana", "cherry"]
for i in thislist:
  print(i)
# Out:
# apple
# banana
# cherry

# %%
thislist = ["apple", "banana", "cherry"]
i = 0
while i < len(thislist):
  print(thislist[i])
  i = i + 1                       #using while loop
# Out:
# apple
# banana
# cherry

# %%
#using for loop.
thislist = ["apple", "banana", "cherry"]
[print(x) for x in thislist]
# Out:
# apple
# banana
# cherry
# [None, None, None]

# %% [markdown]
# List Comprehension
# List comprehension offers a shorter syntax when you want to create a new list based on the values of an existing list.
#
# Example:
#
# Based on a list of fruits, you want a new list, containing only the fruits with the letter "a" in the name.
#
# Without list comprehension you will have to write a for statement with a conditional test inside

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]
newlist = []

for x in fruits:
  if "a" in x:
    newlist.append(x)

print(newlist)                   #without list comprehension
# Out:
# ['apple', 'banana', 'mango']

# %%
fruits = ["apple", "banana", "cherry", "kiwi", "mango"]

newlist = [x for x in fruits if "a" in x]

print(newlist)                                         #with list comprehension
# Out:
# ['apple', 'banana', 'mango']

# %%
#mylist.sort 
#mylist.sort(reverse=true) 
#mylist.reverse

# %%
thislist = ["apple", "banana", "cherry"]
mylist = thislist.copy()
print(mylist)                                    #copy of list

thislist = ["apple", "banana", "cherry"]
mylist = list(thislist)
print(mylist)                                  #same 

thislist = ["apple", "banana", "cherry"]
mylist = thislist[:]
print(mylist)                                #using slice
# Out:
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']
# ['apple', 'banana', 'cherry']

# %%
#there are many way to join or concatenate the lists. 
list1 = ["a", "b", "c"]
list2 = [1, 2, 3]

list3 = list1 + list2
print(list3) 

list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

for x in list2:
  list1.append(x)

print(list1) 

list1 = ["a", "b" , "c"]
list2 = [1, 2, 3]

list1.extend(list2)
print(list1)
# Out:
# ['a', 'b', 'c', 1, 2, 3]
# ['a', 'b', 'c', 1, 2, 3]
# ['a', 'b', 'c', 1, 2, 3]

# %%
#list methods. 
lst = [1, 2, 3]
lst.append(4)

print(lst)   

lst = [1, 2, 3]
lst.clear()

print(lst)   

lst = [1, 2, 3]
new_lst = lst.copy()

print(new_lst)   

lst = [1, 2, 2, 3]
print(lst.count(2))   # it counts the number of occurances of a value. 

lst = [1, 2]
lst.extend([3, 4])

print(lst)   

lst = [10, 20, 30]
print(lst.index(20))   

lst = [1, 2, 3]
lst.insert(1, 100)

print(lst)   

lst = [1, 2, 3]
lst.pop()

print(lst)   #by default it removes the last element.

lst = [1, 2, 3]
lst.reverse()

print(lst)   

lst = [3, 1, 2]
lst.sort()

print(lst)   

lst.sort(reverse=True)
print(lst)              #reverse the sorted list
# Out:
# [1, 2, 3, 4]
# []
# [1, 2, 3]
# 2
# [1, 2, 3, 4]
# 1
# [1, 100, 2, 3]
# [1, 2]
# [3, 2, 1]
# [1, 2, 3]
# [3, 2, 1]

# %%
#removing duplicates from a list 
lst = [1, 2, 2, 3, 4, 4]

unique = []
for x in lst:
    if x not in unique:
        unique.append(x)

print(unique)
# Out:
# [1, 2, 3, 4]

# %%
#find common element between two lists 
lst1 = [1, 2, 3]
lst2 = [2, 3, 4]

common = []

for x in lst1:
    if x in lst2:
        common.append(x)

print(common)
# Out:
# [2, 3]
