# %% [markdown]
# FUNCTION:Functions
# A function is a block of code which only runs when it is called.
# A function can return data as a result.
# A function helps avoiding code repetition.

# %%
def my_function():
  print("Hello from a function")
my_function()
# Out:
# Hello from a function

# %%
#With functions, you write the code once and reuse it 
def fahrenheit_to_celsius(fahrenheit):
  return (fahrenheit - 32) * 5 / 9

#1. Purpose
#print: Displays output on the screen for the user or debugging.
#return: Sends a value from a function back to the caller.
#
#2. Usage
#print: Can be used anywhere in the code to show information.
#return: Only used inside functions to pass data out.
#3. Effect
#print: Does not affect program flow; just shows output.
#return: Ends function execution immediately and provides a value.

#4. Output
#print: Output appears on the console, cannot be stored in a variable.
#return: Output can be stored in a variable or used in expressions.

print(fahrenheit_to_celsius(77))
print(fahrenheit_to_celsius(95))
print(fahrenheit_to_celsius(50))



#We capture the returned value in a variable
morning_temp_f = fahrenheit_to_celsius(20)

# Now we can use that data in a new calculation
if morning_temp_f > 70:
    print(f"It's {morning_temp_f}°F. Wear a t-shirt!")
else:
    print(f"It's {morning_temp_f}°F. Bring a jacket.")
# Out:
# 25.0
# 35.0
# 10.0
# It's -6.666666666666667°F. Bring a jacket.

# %%
#A parameter is the variable listed inside the parentheses in the function definition.

#An argument is the actual value that is sent to the function when it is called. 
def my_function(name): # name is a parameter
  print("Hello", name)

my_function("Emil") # "Emil" is an argument
# Out:
# Hello Emil

# %%
#Using *args to accept any number of arguments:

def my_function(*kids):
  print("The youngest child is " + kids[2])

my_function("Emil", "Tobias", "Linus")
# Out:
# The youngest child is Linus

# %% [markdown]
# iterators:
# Iterator
# An iterator is an object that lets you loop through data one element at a time.
# Uses iter() to create an iterator and next() to get each value.
# When no more values exist, it raises StopIteration.
# All iterators follow the iterator protocol:
#
# iter()
# next()
# Where used
# For loops internally use iterators.Efficient for reading large files line by line.and custom classes.

# %%
mytuple = ("apple", "banana", "cherry")
myit = iter(mytuple)

print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# apple
# banana
# cherry

# %%
#Strings are also iterable objects, containing a sequence of characters
mystr = "banana"
myit = iter(mystr)

print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
print(next(myit))
# Out:
# b
# a
# n
# a
# n
# a

# %%
# A simple list of steps
steps = ["Get ingredients", "Cook food", "Eat"]

# Convert the list into an iterator
chef_bot = iter(steps)

# We use next() to get the first item
print(next(chef_bot))  # Output: Get ingredients

# The iterator 'remembers' where it left off
print("...doing some other work...")
print(next(chef_bot))  # Output: Cook food
# Out:
# Get ingredients
# ...doing some other work...
# Cook food

# %%
class CountDown:
    def __init__(self, start):         #setup process
        self.current = start

    def __iter__(self):                #the start of process.
        return self

    def __next__(self):                 #This is where the actual logic lives. Every time the loop moves to the next iteration, it calls this method.
        if self.current <= 0:
            raise StopIteration  # This tells loops to stop
        
        num = self.current
        self.current -= 1
        return num

# Using our custom iterator in a loop
timer = CountDown(3) 
for tick in timer:
    print(f"T-minus {tick}")

print("Blast off!")
# Out:
# T-minus 3
# T-minus 2
# T-minus 1
# Blast off!

# %% [markdown]
# generators:Generators are functions that can pause and resume their execution.
#
# When a generator function is called, it returns a generator object, which is an iterator.
#
# The code inside the function is not executed yet, it is only compiled. The function only executes when you iterate over the generator.

# %%
def my_generator():
  yield 1
  yield 2
  yield 3

for value in my_generator():
  print(value)
# Out:
# 1
# 2
# 3

# %% [markdown]
# Generators allow you to iterate over data without storing the entire dataset in memory.
#
# Instead of using return, generators use the yield keyword.

# %%
def count_up_to(n):
    count = 1
    while count <= n:  # Use 'n' (the input) as the limit
        yield count    # Send back the current 'count'
        count += 1     # Increase 'count' by 1

for i in count_up_to(5):
    print(i)

#Unlike return, which terminates the function, yield pauses it and can be called multiple times.
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# returns sum of total values
def sum_final(a):
    total = 0
    for x in a:
        total += x
    return total   # gives only final output

values = [1, 2, 3, 4]
print(sum_final(values))   # 10
# Out:
# 10

# %%
# generator that gives the sum at every step
def sum_generator(a):
    total = 0
    for x in a:
        total += x
        yield total   # gives running sum at each step
print(list(sum_generator([1,2,3,4])))
# Out:
# [1, 3, 6, 10]

# %% [markdown]
# Lambda Function:
# A lambda function is a small, anonymous function (no name).
# Created using the lambda keyword.
# Usually used for short, simple operations.
# Can take any number of arguments, but only one expression.

# %%
add = lambda a, b: a + b
print(add(3, 5)) 

mul = lambda a, b: a * b
print(mul(3, 5)) 

func = lambda: "Hello"
print(func())
# Out:
# 8
# 15
# Hello

# %%
#lambda inside function.
def multiplier(n):
    return lambda x: x * n

double = multiplier(2)
print(double(5))
# Out:
# 10

# %% [markdown]
# map():
# Applies a function to each element of an iterable.
# Returns a map object (iterator).
# Used for transformations.

# %%
nums = [4, 5, 6]
res = list(map(lambda x: x * 10, nums))
print(res)
# Out:
# [40, 50, 60]

# %%
# Using Function

def square(x):
    return x*x

print(list(map(square, [2, 4, 6])))
# Out:
# [4, 16, 36]

# %% [markdown]
# reduce()
# reduce() applies a function cumulatively to items in an iterable.
# It reduces a list to one final value.
# You must import it from functools.
# Syntax:
# reduce(function, iterable)

# %%
from functools import reduce

nums = [1, 2, 3, 4]
result = reduce(lambda a, b: a + b, nums)
print(result)  # 10
# Out:
# 10

# %%
words = ["Python", "is", "fun"]
sentence = reduce(lambda a, b: a + " " + b, words)
print(sentence)
# Out:
# Python is fun

# %% [markdown]
# filter():
# filter() is used to select items from an iterable (list, tuple, etc.) based on a condition.
# The condition must return True or False.
# Only values that return True are kept.
#
# Syntax:
# filter(function, iterable)

# %%
nums = [1, 2, 3, 4, 5, 6]
evens = list(filter(lambda x: x % 2 == 0, nums))
print(evens)
# Out:
# [2, 4, 6]

# %%
names = ["ram", "bheem", "Ant", "nun"]
result = list(filter(lambda x: x.startswith("r"), names))
print(result)
# Out:
# ['ram']

# %%
values = ["", "hello", None, "python", ""]
list(filter(lambda x: bool(x), values))
# Out:
# ['hello', 'python']

# %% [markdown]
# File Operations in Python
# Python provides built-in functions to work with files — reading, writing, appending, deleting, etc.
#
# The first with open(..., "w") block creates or overwrites the file and writes multiple lines of text into it.
# Each f.write() adds one line of text to the file.
# The second with open(..., "r") block opens the same file in read mode.
# f.read() reads the entire file content and prints it to the screen.

# %%
# Writing to a text file
with open("example.txt", "w") as f:
    f.write("Hello, my name is ram.\n")
    f.write("I am learning Python file handling.\n")
    f.write("This is a sample text written to the file.\n")
    f.write("End of the file.")

# Reading from a text file
with open("example.txt", "r") as f:
    content = f.read()
    print("File content:")
    print(content)
# Out:
# File content:
# Hello, my name is ram.
# I am learning Python file handling.
# This is a sample text written to the file.
# End of the file.

# %% [markdown]
# Reading line-by-line
# Open the file using with open("file.txt") so it closes automatically.
# Loop through the file using for line in f: to read one line at a time.
# Use strip() to remove the newline character (\n).
# This method is memory-efficient and works even for large files

# %%
with open("example.txt", "r") as f:
    lines = f.readlines()
    for line in lines:
        print(line.strip())
# Out:
# Hello, my name is ram.
# I am learning Python file handling.
# This is a sample text written to the file.
# End of the file.

# %%
with open("example.txt", "w") as f:
    f.write("\nram is practicing Python step by step.")
    f.write("\nFile operations are becoming easier each day.")
    f.write("\nWriting and reading files is an important concept.")
    f.write("\nram will continue exploring more Python topics.")

# %%
with open("example.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# ram is practicing Python step by step.
# File operations are becoming easier each day.
# Writing and reading files is an important concept.
# ram will continue exploring more Python topics.

# %% [markdown]
# Append
# "a" adds new content at the end of the file without deleting existing data.
# If the file doesn't exist, append mode automatically creates it.
# Each write() call adds text where the previous file content ends.
# Use "\n" to move to a new line when appending multiple lines.

# %%
with open("example.txt", "a") as f:
    f.write("\nFile handling is an essential Python skill.")
    f.write("\nAppending allows adding content without losing existing data.")

# %%
with open("example.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# ram is practicing Python step by step.
# File operations are becoming easier each day.
# Writing and reading files is an important concept.
# ram will continue exploring more Python topics.

# %%
with open("example.txt", "r") as file:
    print("I created this file:", file.read())
# Out:
# I created this file:
# ram is practicing Python step by step.
# File operations are becoming easier each day.
# Writing and reading files is an important concept.
# ram will continue exploring more Python topics.

# %% [markdown]
# read line by line
# Use with open("file.txt", "r") to safely open a file for reading.
# Loop through the file using for line in f: to read one line at a time.
# strip() removes the newline character (\n) from each line.
# This method is memory-efficient and works well for large files.

# %%
with open("example.txt", "r") as f:
    line = f.readline()
    while line:
        print(line.strip())
        line = f.readline()
# Out:
# ram is practicing Python step by step.
# File operations are becoming easier each day.
# Writing and reading files is an important concept.
# ram will continue exploring more Python topics.

# %%
with open("example.txt", "r") as f:
    lines = f.readlines()
    print(lines)
    for line in lines:
        print(line.strip())
# Out:
# ['\n', 'ram is practicing Python step by step.\n', 'File operations are becoming easier each day.\n', 'Writing and reading files is an important concept.\n', 'ram will continue exploring more Python topics.']
#
# ram is practicing Python step by step.
# File operations are becoming easier each day.
# Writing and reading files is an important concept.
# ram will continue exploring more Python topics.

# %% [markdown]
# copy file
# Use the shutil module to easily copy files.
# shutil.copy() copies the file content to a new file.
# shutil.copy2() copies the file along with metadata like timestamps.
# You can also copy manually by reading the source file and writing line by line to a new file

# %%
with open("example.txt", "r") as source:
    with open("sample_manual_copy.txt", "w") as dest:
        for line in source:
            dest.write(line)
print("File copied manually line by line.")
# Out:
# File copied manually line by line.

# %%
import shutil
# Copy source file to destination
shutil.copy("example.txt", "sample_copy.txt")
print("File copied successfully.")
# Out:
# File copied successfully.

# %%
with open("sample_copy.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# ram is practicing Python step by step.
# File operations are becoming easier each day.
# Writing and reading files is an important concept.
# ram will continue exploring more Python topics.

# %% [markdown]
# r+" mode allows reading and writing in the same file without erasing it.
# seek(position) moves the cursor, and write() overwrites text starting from that position

# %%
with open("example.txt", "r+") as file:
    content = file.read()       # Reads the entire file
    file.seek(34)               # Moves the cursor to position 35
    file.write(" newly added line ") # Overwrites text starting from position 35

# %%
with open("example.txt", "r") as file:
    content = file.read()
    print(content)
# Out:
# ram is practicing Python step by newly added line tions are becoming easier each day.
# Writing and reading files is an important concept.
# ram will continue exploring more Python topics.

# %% [markdown]
# Working with Excel Files (.xlsx)
# Use pd.DataFrame() to create tabular data in Python.
# Save a DataFrame to Excel using df.to_excel("filename.xlsx", index=False).
# Read an Excel file back into a DataFrame using pd.read_excel("filename.xlsx").
# Pandas makes it easy to manipulate, filter, and analyze Excel data before or after saving

# %%
import pandas as pd

# Sample data: Employee info
data = {
    "EmployeeID": [101, 102, 103, 104],
    "Name": ["John", "Emma", "Liam", "Olivia"],
    "Department": ["HR", "Finance", "IT", "Marketing"],
    "Salary": [50000, 60000, 55000, 65000]
}

# Create a DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print("Original DataFrame:")
print(df)

# Write to a CSV file (works without extra libraries)
df.to_csv("employees.csv", index=False)    #When index=True, Pandas saves index values as an extra column, and when reading it back, it appears as a normal column (often named Unnamed: 0)
    

# Read from the CSV file
df_read = pd.read_csv("employees.csv")
print("\nData read from CSV:")
print(df_read)
# Out:
# Original DataFrame:
#    EmployeeID    Name Department  Salary
# 0         101    John         HR   50000
# 1         102    Emma    Finance   60000
# 2         103    Liam         IT   55000
# 3         104  Olivia  Marketing   65000
#
# Data read from CSV:
#    EmployeeID    Name Department  Salary
# 0         101    John         HR   50000
# 1         102    Emma    Finance   60000
# 2         103    Liam         IT   55000
# 3         104  Olivia  Marketing   65000
