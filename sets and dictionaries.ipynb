# %% [markdown]
# TUPLES:
# Tuples are used to store multiple items in a single variable.
#
# Tuple is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Set, and Dictionary, all with different qualities and usage.
#
# A tuple is a collection which is ordered and unchangeable.
#
# Tuples are written with round brackets.
# Tuple items are ordered, unchangeable, and allow duplicate values.
#
# Tuple items are indexed, the first item has index [0], the second item has index [1] etc.

# %%
thistuple = ("apple", "banana", "cherry")
print(thistuple) 
print(len(thistuple))
# Out:
# ('apple', 'banana', 'cherry')
# 3

# %%
 #count()
t1 = (1, 2, 2)
print(t1.count(2))

# index()
t2 = (10, 20, 30)                     #tuple methods.
print(t2.index(20))
# Out:
# 2
# 1

# %%
thistuple = ("apple",)
print(type(thistuple))  #o create a tuple with only one item, you have to add a comma after the item, otherwise Python will not recognize it as a tuple
# Out:
# <class 'tuple'>

# %%
#Once a tuple is created, you cannot change its values. Tuples are unchangeable, or immutable as it also is called.
#But there is a workaround. You can convert the tuple into a list, change the list, and convert the list back into a tuple.

x = ("apple", "banana", "cherry")
y = list(x)
y[1] = "kiwi"
x = tuple(y)

print(x)
# Out:
# ('apple', 'kiwi', 'cherry')

# %%
thistuple = ("apple", "banana", "cherry")
del thistuple
print(thistuple)  #you can delete the tuple directly.but when you perform append or remove operations you should covert it to a list.

# %%
tuple1 = ("a", "b" , "c")
tuple2 = (1, 2, 3)

tuple3 = tuple1 + tuple2
print(tuple3)                            # joining two tuples  

tuple1 = ("a", "b" , "c")

tuple2 = tuple1 * 2                    #multiply
print(tuple2)
# Out:
# ('a', 'b', 'c', 1, 2, 3)
# ('a', 'b', 'c', 'a', 'b', 'c')

# %% [markdown]
# Sets:
# Sets are used to store multiple items in a single variable.
#
# Set is one of 4 built-in data types in Python used to store collections of data, the other 3 are List, Tuple, and Dictionary, all with different qualities and usage.
#
# A set is a collection which is unordered, unchangeable*, and unindexed.

# %%
thisset = {"apple", "banana", "cherry"}
print(thisset) 

thisset = {"apple", "banana", "cherry", "apple"}

print(thisset)                         #duplicates not allowed
# Out:
# {'banana', 'apple', 'cherry'}
# {'banana', 'apple', 'cherry'}

# %%
 #True and 1 are considered the same value in sets,false  and 0 are considered the same value in sets.
thisset = {"apple", "banana", "cherry"}

thisset.add("orange")

print(thisset)                                 #Once a set is created, you cannot change its items, but you can add new items. 

#you can also use update to combine multiple sets. 

thisset = {"apple", "banana", "cherry"}
mylist = ["kiwi", "orange"]

thisset.update(mylist)

print(thisset)

thisset = {"apple", "banana", "cherry"}

thisset.remove("banana")                          #To remove an item in a set, use the remove(), or the discard() method.

print(thisset)

s = {1, 2, 3}
s.pop()
print(s)                                    #using pop it removes the random item.

#The union() and update() methods joins all items from both sets.

#The intersection() method keeps ONLY the duplicates. 

set1 = {"a", "b", "c"}
set2 = {1, 2, 3}

set3 = set1.union(set2)
print(set3) 

a = {1, 2, 3}
b = {2, 3, 4}
a.intersection(b)
# Out:
# {'banana', 'apple', 'cherry', 'orange'}
# {'kiwi', 'banana', 'cherry', 'orange', 'apple'}
# {'apple', 'cherry'}
# {2, 3}
# {1, 'b', 2, 3, 'a', 'c'}
# {2, 3}

# %%
#frozenset is an immutable version of a set.

#Like sets, it contains unique, unordered, unchangeable elements.

#Unlike sets, elements cannot be added or removed from a frozenset.

x = frozenset({"apple", "banana", "cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'banana', 'apple', 'cherry'})
# <class 'frozenset'>

# %% [markdown]
# DICTIONARY:
# A dictionary stores key–value pairs.
# Keys must be unique; values can repeat. which is ordered*, changeable and do not allow duplicates.
# Mutable and unordered.
# Fast lookups using keys.
# Good for structured data

# %%
student = {"name": "ram", "age": 24}
print(student["name"]) 

car = {
"brand": "Ford",
"model": "Mustang",
"year": 1964        
}

x = car.keys()

print(x) #before the change 

car["color"] = "white"

print(x)
# Out:
# ram
# dict_keys(['brand', 'model', 'year'])
# dict_keys(['brand', 'model', 'year', 'color'])

# %% [markdown]
# SHALLOW COPY
# Copies outer structure but shares inner objects.
# Inner lists remain linked.
# Changing nested data affects both copies.
# Fast but unsafe for deep structures.
# Created using copy(), slicing.

# %%
a = [[1, 2], [3, 4]]
b = a.copy()
print(b)
# Out:
# [[1, 2], [3, 4]]

# %%
b[0][1] = 5
print(b)
print(a)
# Out:
# [[1, 5], [3, 4]]
# [[1, 5], [3, 4]]

# %% [markdown]
# DEEP COPY
# Creates fully independent copies including nested structures.
# Inner objects copied too.
# Changes do NOT affect original.
# Slower but safe.
# Best for nested objects.

# %%
import copy
a = [[1, 2], [3, 4]]
b = copy.deepcopy(a)

# %%
b[0][1] = 5
print(a)
print(b)
# Out:
# [[1, 2], [3, 4]]
# [[1, 5], [3, 4]]

# %%
#The keys() method will return a list of all the keys in the dictionary. 

#Nested Dictionaries
#A dictionary can contain dictionaries, this is called nested dictionaries 

myfamily = {
  "child1" : {
    "name" : "Emil",
    "year" : 2004
  },
  "child2" : {
    "name" : "Tobias",
    "year" : 2007
  },
  "child3" : {
    "name" : "Linus",
    "year" : 2011
  }
}
print(myfamily["child2"]["name"])
# Out:
# Tobias
